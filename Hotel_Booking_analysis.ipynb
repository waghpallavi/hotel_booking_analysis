# %% [markdown]
# <a href="https://colab.research.google.com/github/waghpallavi/hotel_booking_analysis/blob/main/Hotel_Booking_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Team
# ##### **Team Member 1 -** Pallavi Wagh
# ##### **Team Member 2 -** Monika Raj

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The hotel sector is very unpredictable, and bookings depend on a wide range of variables, including hotel type, seasonality, day of the week, and many more. To assist the hotels in making better plans, it is now even more crucial to analyse the patterns present in the historical data. In order to increase revenue, hotels can run a number of initiatives using past data. We can predict future bookings using the patterns.
#
# The data we have will be used to study the variables influencing hotel reservations. These variables can be used to predict upcoming reservations and report trends.
#
# Our primary goal is to conduct EDA on the provided dataset and generate insightful conclusions regarding general hotel booking trends and the factors affecting hotel bookings

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# [https://github.com/waghpallavi/hotel_booking_analysis.git](https://)

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
#  This project includes a record of hotel reservations for a city and a resort hotel from 2015 to 2017. It includes information on reservations, cancellations, and guest information. The main goal of the project is to understand and visualise data from the hotel and customer perspectives, such as the best time to book a hotel, peak season, and reasons for cancellations throughout varying factors. to provide recommendations to decrease these cancellations and boost hotel revenue.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To provide recommendations to decrease these cancellations and boost hotel revenue.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
path = '/content/drive/MyDrive/Colab Notebooks/Almabetter/Capstone project/EDA Project on Hotel Booking analysis/Hotel Bookings.csv'
df = pd.read_csv(path)
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
row_count = len(df)
row_count
# Out:
# 119390

# %%
column_count = len(df.columns)
column_count
# Out:
# 32

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])
# Out:
# 31994

# %%
# Dropping duplicate values
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (87396, 32)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
# Visualizing the missing values
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# Removing the columns with large number of null values from the dataframe.
clean_df = df.drop(['company','agent'], axis = 1)
clean_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
# Changing null values in 'country' column to 'others'
clean_df['country'].fillna('others', inplace=True)

# %%
# Changing null values in 'children' column to mean of all values
clean_df['children'].fillna(round(df.children.mean()), inplace=True)

# %%
# converting datatype of 'children' columns from float to integer
clean_df['children'] = clean_df['children'].astype('int64')

# %%
# converting datatype of 'reservation_status_date' to datetime.
clean_df['reservation_status_date'] = pd.to_datetime(clean_df['reservation_status_date'], format = '%Y-%m-%d')

# %%
# Checking if all null values are removed
clean_df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
# Creating new column 'total_stay'
clean_df['total_stay'] = clean_df['stays_in_weekend_nights'] + clean_df['stays_in_week_nights']

# %%
# Creating another column 'total_pople'
clean_df['total_people'] = clean_df['adults'] + clean_df['children'] + clean_df['babies']

# %%
# Adding revenue column
clean_df['revenue'] = clean_df['total_stay'] * clean_df['adr']

# %%
clean_df.shape
# Out:
# (87396, 33)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This dataset contains hotel booking information, we will conduct exploratory data analysis to obtain insight from the data. The above dataset has 87396 rows and 33 columns. There are no mising values and duplicate values in the dataset.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
clean_df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'total_stay',
#        'total_people', 'revenue'],
#       dtype='object')

# %%
# Dataset Describe
clean_df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  87396.000000  87396.000000       87396.000000
# mean       0.274898     79.891368        2016.210296
# std        0.446466     86.052325           0.686102
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87396.000000               87396.000000
# mean                  26.838334                  15.815541
# std                   13.674572                   8.835146
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %% [markdown]
#  **Variables Description**

# %% [markdown]
# **hotel :** Name of the hotel (Resort Hotel or City Hotel)
#
# **is_canceled :** If the booking was canceled (1) or not (0)
#
# **lead_time :** Number of days before the actual arrival of the guests
#
# **arrival_date_year :** Year of arrival date
#
# **arrival_date_month :** Month of month arrival date
#
# **arrival_date_week_number :** Week number of year for arrival date
#
# **arrival_date_day_of_month :** Day of arrival date
#
# **stays_in_weekend_nights :** Number of weekend nights (Saturday or Sunday) spent at the hotel by the guests.
#
# **stays_in_week_nights :** Number of weeknights (Monday to Friday) spent at the hotel by the guests.
#
# **adults :** Number of adults among guests
#
# **children :** Number of children among guests
#
# **babies :** Number of babies among guests
#
# **meal :** Type of meal booked
#
# **country :** Country of guests
#
# **distribution_channel :** Name of booking distribution channel
#
# **is_repeated_guest :** If the booking was from a repeated guest (1) or not (0)
#
# **previous_cancellations :** Number of previous bookings that were cancelled by the customer prior to the current booking
#
# **previous_bookings_not_canceled :** Number of previous bookings not cancelled by the customer prior to the current booking
#
# **reserved_room_type :** Code of room type reserved
#
# **assigned_room_type :** Code of room type assigned
#
# **booking_changes :** Number of changes/amendments made to the booking
#
# **deposit_type :** Type of the deposit made by the guest
#
# **agent :** ID of travel agent who made the booking
#
# **company :** ID of the company that made the booking
#
# **days_in_waiting_list :** Number of days the booking was in the waiting list
#
# **customer_type :** Type of customer, assuming one of four categories
#
# **adr :** Average Daily Rate, as defined by dividing the sum of all lodging transactions by the total number of staying nights
#
# **required_car_parking_spaces :** Number of car parking spaces required by the customer
#
# **total_of_special_requests :** Number of special requests made by the customer
#
# **reservation_status :** Reservation status (Canceled, Check-Out or No-Show)
#
# **reservation_status_date :** Date at which the last reservation status was updated

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in clean_df.columns.tolist():
  uni_value = clean_df[i].nunique()
  print(f"No. of unique values in ",i,"is",uni_value,".")
# Out:
# No. of unique values in  hotel is 2 .
# No. of unique values in  is_canceled is 2 .
# No. of unique values in  lead_time is 479 .
# No. of unique values in  arrival_date_year is 3 .
# No. of unique values in  arrival_date_month is 12 .
# No. of unique values in  arrival_date_week_number is 53 .
# No. of unique values in  arrival_date_day_of_month is 31 .
# No. of unique values in  stays_in_weekend_nights is 17 .
# No. of unique values in  stays_in_week_nights is 35 .
# No. of unique values in  adults is 14 .
# No. of unique values in  children is 5 .
# No. of unique values in  babies is 5 .
# No. of unique values in  meal is 5 .
# No. of unique values in  country is 178 .
# No. of unique values in  market_segment is 8 .
# No. of unique values in  distribution_channel is 5 .
# No. of unique values in  is_repeated_guest is 2 .
# No. of unique values in  previous_cancellations is 15 .
# No. of unique values in  previous_bookings_not_canceled is 73 .
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %%
# Write your code to make your dataset analysis ready.
ready_df=clean_df.copy()
ready_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# #### **Univariate Analysis**

# %% [markdown]
# Univariate analysis is a type of analysis that only uses one variable. In practice, a univariate analysis is the examination of a single variable in a dataset.

# %% [markdown]
# #### **Let's see which type of hotel is preferred.**

# %%
# We will write a function that plots a pie chart using grouped count values so that it can be reused in the future.

# Function for Column Value Counts

def column_value_count(df, column_label):
  df_grpd = df[column_label].value_counts()
  df_grpd = pd.DataFrame({'index':df_grpd.index, 'count':df_grpd.values})
  return df_grpd


# function for visulization of pie chart
def plot_pie_chart_from_column(df, column_label):
  df_grpd = column_value_count(df, column_label)
  fig, ax = plt.subplots(figsize=(14, 6))
  ax.pie(df_grpd.loc[:, 'count'], labels=df_grpd.loc[:, 'index'],explode=[0,0.1],autopct='%1.2f%%', startangle=90, colors=['#A2C3DB','#8871A0'])
  plt.show()

# %%
# plot a pie chart to show % of bookings from each hotel
plot_pie_chart_from_column(ready_df, 'hotel')

# %% [markdown]
# City Hotel has 1.6 times the number of bookings as Resort Hotel. City Hotel appears to be more popular among visitors.

# %% [markdown]
# **We will now determine how frequently repeated customers occur.**

# %%
# pie chart to show % of repeated guests
plot_pie_chart_from_column(ready_df, 'is_repeated_guest')

# %% [markdown]
# Repeated customers make up a very small percentage of bookings (around 4%). As a result, the retention rate is extremely low.

# %% [markdown]
# **We will now calculate the percentage of cancelled bookings.**

# %%
# pie chart to show % of cancelled bookings
plot_pie_chart_from_column(ready_df, 'is_canceled')

# %% [markdown]
# We can see that approximately one-fourth of all bookings are cancelled.

# %%
# Column Value Counts
print(ready_df.customer_type.value_counts())
# Out:
# Transient          71986
# Transient-Party    11727
# Contract            3139
# Group                544
# Name: customer_type, dtype: int64

# %%
# pie chart to show % of types of customers
ready_df['customer_type'].value_counts().plot.pie(figsize=(20,10),autopct="%1.2f%%",explode=[0,0.1,0.1,0.2],startangle=90,colors=['#A2C3DB','#8871A0','#8AAF22','#3F9F9F'])
# Out:
# <Axes: ylabel='customer_type'>

# %% [markdown]
# 1. **Contract**
#
# when the booking has an allotment or other type of contract associated to it
#
# 2. **Group**
#
# when the booking is associated to a group
#
# 3. **Transient**
#
# when the booking is not part of a group or contract, and is not associated to other transient booking
#
# 4. **Transient-party**
#
# when the booking is transient, but is associated to at least other transient booking

# %% [markdown]
# The majority of the clients (82.37%) were of the transient type, while 13.42% of the  were transient parties and 3.59% were of the contract type. The remaining 0.62% is  group type.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart depicts the portion relationship of your data. The area covered in a circle with different colours makes it easy to see how the percentages compare.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. The most popular hotel type among visitors is the city hotel. Most likely the busiest hotel type amongst given types.
# 2. There is a very small percentage of repeated customers.
# 3. About one-fourth of reservations are cancelled.
# 4. Maximum number of customers are transient type. while group type is lowest.

# %% [markdown]
# #####3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The hotel industry can use this information to target clients because it can identify the primary consumer behaviors.

# %% [markdown]
# **Let's see which room type is the most popular among visitors.**

# %%
# We will now write a code to plot a bar graph to determine the most popular room choices among customers.

fig, ax = plt.subplots(figsize=(15, 5),dpi=150)
grp_by_room = ready_df.groupby('assigned_room_type')
df['Num_of_bookings'] = grp_by_room.size()
sns.countplot(x = df['assigned_room_type']).set_title("Popular room choices among customers")
plt.show()

# %% [markdown]
# Room Type A is the most often booked room type by tourists. Therefore, Room Type A is the most popular room type followed by room type D and E.

# %% [markdown]
# **We will now identify the room type that produces the highest adr.**

# %%
# Boxplot to determine highest adr producing room type
fig, ax = plt.subplots(figsize=(15, 10),dpi=150)
sns.boxplot( x = ready_df['assigned_room_type'], y = ready_df['adr'])
plt.show()

# %% [markdown]
# H, G, and F room types provide higher adr.

# %% [markdown]
# **Let's look at the most popular meal type among consumers.**

# %%
plt.figure( figsize=(10,5),dpi=200)
sns.countplot(x = ready_df['meal']).set_title("Popular meal type among consumers")
plt.show()

# %% [markdown]
# Most preferred meal type is BB (Bed and breakfast)

# %% [markdown]
# **Let's see which month had the most bookings.**

# %%
# groupby arrival_date_month and taking the hotel count
bookings_by_months_df= ready_df.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':"Counts"})
# Create list of months in order
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
# creating df which will map the order of above months list without changing its values.
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)
# sorting by arrival_date_month
bookings_by_months_df=bookings_by_months_df.sort_values('arrival_date_month')

bookings_by_months_df
# Out:
#    arrival_date_month  Counts
# 4             January    4693
# 3            February    6098
# 7               March    7512
# 0               April    7908
# 8                 May    8355
# 6                June    7765
# 5                July   10057
# 1              August   11257
# 11          September    6690
# 10            October    6934
# 9            November    4995
# 2            December    5131

# %%
# set plot size
plt.figure(figsize=(20,8))

#pltting lineplot on x- months & y- booking counts
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['Counts'])

# set title for the plot
plt.title('Number of bookings across each month')
#set x label
plt.xlabel('Month')
#set y label
plt.ylabel('Number of bookings')
# Out:
# Text(0, 0.5, 'Number of bookings')

# %% [markdown]
# The months of July and August had the most bookings.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1.   The patterns or relationships between the various variables are displayed in a bar graph. They provide quick data interpretation and a wide variety of increased analysis.
# 2.   Box plots assist in the visualization of quantitative value distributions. They can also be used to compare categorical variables and identify outliers.
# 3.   An representation of data frequency along a number line is a line plot. It is a quick and easy method of data organization.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.   The most popular room type is therefore Room Type A, which is followed by Room Type D and Room Type E.
# 2.   High adr is provided by room types H, G, and F.
# 3.   BB is the most popular form of meal type.
# 4.   The months of July and August had the most bookings. The bookings could be due to a summer holiday.

# %% [markdown]
# #####3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1. To boost revenue, hotels should expand the quantity of room categories A, G, F, and H.
# 2. Collaborate with nearby cafés, eateries, breweries, and vineyards to enhance customer experience by providing guests with a genuine experience.

# %% [markdown]
# **The ratio of bookings made for the City Hotel and the Resort Hotel**

# %%
# apply groupby function on 'hotel' column
grouped_by_hotel = ready_df.groupby('hotel')

# create DataFrame
d1 = pd.DataFrame((grouped_by_hotel.size()/ready_df.shape[0])*100).reset_index().rename(columns = {0:'Booking %'})      # Percentage calculations

# code to plot bar graph
plt.figure(figsize = (8,5),dpi=150)
sns.barplot(x = d1['hotel'], y = d1['Booking %']).set_title("Hotel booking comparison")
plt.show()

# %% [markdown]
# Around 60% bookings are for City hotel and 40% bookings are for Resort hotel.

# %% [markdown]
# **Which hotel has higher lead time?**

# %%
# create DataFrame
d2 = grouped_by_hotel['lead_time'].median().reset_index().rename(columns = {'lead_time':'median_lead_time'})

# code to plot bar graph
plt.figure(figsize = (8,5),dpi=150)
sns.barplot(x = d2['hotel'], y = d2['median_lead_time'] ).set_title("Lead time for hotels")
plt.show()

# %% [markdown]
# City hotel has slightly higher median lead time.

# %% [markdown]
# **which hotel seems to make more revenue?**

# %%
# create DataFrame
d3 = grouped_by_hotel['adr'].agg(np.mean).reset_index().rename(columns = {'adr':'avg_adr'})   # calculating average adr

# %%
# code to plot bar graph
plt.figure(figsize = (8,5), dpi=150)
sns.barplot(x = d3['hotel'], y = d3['avg_adr'] )
plt.show()

# %% [markdown]
# Avg adr of Resort hotel is slightly lower than that of City hotel.

# %% [markdown]
# **Now we'll look at the ideal length of stay at each hotel.**

# %%
not_canceled = ready_df[ready_df['is_canceled'] == 0]
s1 = not_canceled[not_canceled['total_stay'] < 15]
plt.figure(figsize = (10,5),dpi=150)
sns.countplot(x = s1['total_stay'], hue = s1['hotel'])
plt.show()

# %% [markdown]
# The usual length of stay is less than four days.

# %% [markdown]
# **Waiting time comparison between hotels**

# %%
# create DataFrame
d5 = pd.DataFrame(grouped_by_hotel['days_in_waiting_list'].agg(np.mean).reset_index().rename(columns = {'days_in_waiting_list':'avg_waiting_period'}))

# code to plot bar graph
plt.figure(figsize = (10,5), dpi=150)
sns.barplot(x = d5['hotel'], y = d5['avg_waiting_period'] )
plt.show()

# %% [markdown]
# City hotel has significantly longer waiting time

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar graphs provide a visual representation of data. They are used to show the relationship between two or more different types of data visually. To make the large amount of information easier to interpret visually, it is summarized in a bar graph. It offers a more detailed explanation of the patterns of the data than the table. It helps in quickly estimating the important values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Compared to resort hotels, city hotels have significantly more bookings.
# 2. The median lead time for a city hotel is slightly longer.
# 3. The adr at Resort hotels is a little lower than at City hotels.
# 4. Length of stay is less than four days.
# 5. The waiting period at a city hotel is considerably longer.

# %% [markdown]
# #####3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1. 40% of reservations are for resort hotels, while 60% are for city hotels. Since resort hotels have a somewhat lower adr, city hotels appear to be slightly more profitable.
# 2. Every case has a significantly higher median lead time, which shows that travellers frequently reserve their hotel stays well in advance. Hotels can use strategies like discounts and customised experiences to encourage customers to book in advance.
# 3. Most people choose city hotels for short stays, while resort hotels are preferred for extended stays. Resort hotels is substantially less crowded than City hotels. Therefore, travelers stay at resort hotels for very relaxing stays. In light of the above insights, hotels can take a few significant steps.

# %% [markdown]
# **let's check which nation is generating the most tourists.**

# %%
# Counting the guests from various countries.
country_df=ready_df['country'].value_counts().reset_index().rename(columns={'index': 'country','country': 'count of guests'})[:10]

# %%
# Visualizing by  plotting the graph
plt.figure(figsize=(20,8))
sns.barplot(x=country_df['country'],y=country_df['count of guests'])
plt.xlabel('Country')
plt.ylabel('Number of guests',fontsize=12)
plt.title("Number of guests from diffrent Countries")
# Out:
# Text(0.5, 1.0, 'Number of guests from diffrent Countries')

# %%
#importing the folium library
import folium                                # searched on google 
import plotly.express as px

# %%
basemap = folium.Map()
guests_map = px.choropleth(country_df, locations = country_df['country'],color = country_df['count of guests'], hover_name = country_df['country'])
guests_map.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The majority of visitors are from Portugal, with over 25000 visitors from that region.

# %% [markdown]
# # **2. Bivariate Analysis**

# %% [markdown]
# A bivariate analysis is defined as an examination of any concurrent relationship between two variables or attributes.

# %% [markdown]
# Lets take a look at the revenue generated by each hotel.

# %%
plt.figure(figsize=(4,2),dpi=200)
sns.barplot(data=ready_df,x='hotel',y='revenue',estimator=sum),
plt.show()

# %% [markdown]
# The revenue generated by a city hotel exceeds that of a resort hotel.

# %% [markdown]
# **Let's see which hotels have a greater chance of repeat customers.**

# %%
# Selecting and counting repeated customers bookings
repeated_data = ready_df[ready_df['is_repeated_guest'] == 1]
repeat_grp = repeated_data.groupby('hotel')
D1 = pd.DataFrame(repeat_grp.size()).rename(columns = {0:'total_repeated_guests'})

# Counting total bookings
total_booking = grouped_by_hotel.size()
D2 = pd.DataFrame(total_booking).rename(columns = {0: 'total_bookings'})
D3 = pd.concat([D1,D2], axis = 1)

plt.figure(figsize=(10,5),dpi=150)
sns.countplot(data=ready_df,x='hotel',hue='is_repeated_guest')
plt.show()

# %%
# Calculating repeat %
D3['repeat_%'] = round((D3['total_repeated_guests']/D3['total_bookings'])*100,2)

plt.figure(figsize = (10,5),dpi=150)
sns.barplot(x = D3.index, y = D3['repeat_%'])
plt.show()

# %% [markdown]
# Only a relatively small percentage of customers at both hotel return.

# %% [markdown]
# **Bar graph to represent the repeated and non-repeated
# bookings in each distribution channel**

# %%
pd.crosstab(index = df['is_repeated_guest'],columns = df['distribution_channel'])
# Out:
# distribution_channel  Corporate  Direct  GDS  TA/TO  Undefined
# is_repeated_guest
# 0                          3542   12071  178  68185          5
# 1                          1539     917    3    956          0

# %%
round(pd.crosstab(index = df['is_repeated_guest'],
                  columns = df['distribution_channel'],
                  normalize='index')*100,2)
# Out:
# distribution_channel  Corporate  Direct   GDS  TA/TO  Undefined
# is_repeated_guest
# 0                          4.22   14.37  0.21  81.19       0.01
# 1                         45.07   26.85  0.09  27.99       0.00

# %%
plt.figure(figsize=(10,5),dpi=150)
sns.countplot(data=ready_df,x='distribution_channel',hue='is_repeated_guest')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar graphs provide a visual representation of data. They are used to show the relationship between two or more different types of data visually. To make the large amount of information easier to interpret visually, it is summarized in a bar graph. It offers a more detailed explanation of the patterns of the data than the table. It helps in quickly estimating the important values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Avg adr of Resort hotel is slightly lower than that of City hotel.
# 2. Both hotels have very small percentage that customer will repeat.
# 3. The TA/TO channel is used for the most of  repeated bookings.

# %% [markdown]
# #####3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1. Investments in city hotels will be profitable because they generate more revenue.
# 2. The likelihood that a customer will return to either hotel is extremely low, although Resort Hotel has a slightly greater rate of repeat business than City Hotel.

# %% [markdown]
# # Hotel wise Cancellation

# %%
# Selecting and counting number of cancelled bookings for each hotel.
cancelled_data = ready_df[ready_df['is_canceled'] == 1]
cancel_grp = cancelled_data.groupby('hotel')
D1 = pd.DataFrame(cancel_grp.size()).rename(columns = {0:'total_cancelled_bookings'})

# Counting total number of bookings for each type of hotel
grouped_by_hotel = ready_df.groupby('hotel')
total_booking = grouped_by_hotel.size()
D2 = pd.DataFrame(total_booking).rename(columns = {0: 'total_bookings'})
D3 = pd.concat([D1,D2], axis = 1)
D3
# Out:
#               total_cancelled_bookings  total_bookings
# hotel
# City Hotel                       16049           53428
# Resort Hotel                      7976           33968

# %%
plt.figure(figsize=(10,5),dpi=150)
sns.countplot(data=ready_df,x='hotel',hue='is_canceled',palette = 'Set1')
plt.show()

# %%
# Calculating cancel percentage 
D3['cancel_%'] = round((D3['total_cancelled_bookings']/D3['total_bookings'])*100,2)

plt.figure(figsize = (10,5),dpi=150)
sns.barplot(x = D3.index, y = D3['cancel_%'])
plt.show()

# %% [markdown]
# Almost 30% of reservations for City Hotels and 25% for resort hotels were cancelled.

# %% [markdown]
# **Let us explore what causes customers to cancel their hotel booking.**

# %% [markdown]
# One question that can come up is whether a longer waiting period or longer lead time results in booking cancellations.
# let us check

# %% [markdown]
# Due to the extremely high number of records with zero waiting list days, only non-zero data is taken into account here.

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
sns.kdeplot(data = ready_df[ready_df['days_in_waiting_list'] != 0], ax = axes[0], x = 'days_in_waiting_list', hue = 'is_canceled')
sns.kdeplot(data = ready_df, ax = axes[1], x = 'lead_time', hue = 'is_canceled')
plt.show()

# %% [markdown]
# For both cancelled and non-cancelled bookings, the density plot of lead time and the number of days on the waiting list peaks at the same location and takes on a nearly identical form.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The density plot can control the distortion and smooth out the value distribution. It depicts how data is distributed over a specific time period, and the peaks identify the areas with highest density of values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Almost 30% of reservations for City Hotels and 25% for resort hotels were cancelled.
# 2. As both cancelled and non-cancelled bookings, the density plot of lead time and the number of days on the waiting list peaks at the same location and takes on a nearly identical form, The lead time and the number of days on the waiting list have no impact on booking cancellations.

# %% [markdown]
# **Let us find correlation between booking cancallations and hotels**

# %%
plt.figure(figsize=(4,2),dpi=200)
sns.heatmap(pd.crosstab(index = df['is_canceled'],columns = df['hotel']),annot=True, linewidth=1)
plt.show()

# %% [markdown]
# # **Multivariate** **Analysis**

# %% [markdown]
# #### Let's start by determining the correlation between the numerical data.

# %% [markdown]
# First, determine the relationship between the numerical data.
#
# Columns such as 'is_cancelled,' 'arrival_date_year', 'arrival_date_week_number', 'arrival_date_day_of_month', and 'is_repeated_guest' are numerically typed categorical data. As a result, we won't need to check them for correlation.
#
#
# We've also included 'total_stay' and 'total_people' columns. As a result, we can delete the columns 'adults', 'children', 'babies', 'stays_in_weekend_nights', and 'stays_in_weeknights'.

# %%
ready_df.corr()
# Out:
#                                 is_canceled  lead_time  arrival_date_year  \
# is_canceled                        1.000000   0.184806           0.088030
# lead_time                          0.184806   1.000000           0.139135
# arrival_date_year                  0.088030   0.139135           1.000000
# arrival_date_week_number           0.001443   0.101150          -0.514228
# arrival_date_day_of_month          0.005328   0.009866          -0.010023
# stays_in_weekend_nights            0.060191   0.235145           0.005144
# stays_in_week_nights               0.082928   0.310129           0.003645
# adults                             0.081816   0.140493           0.038619
# children                           0.067369   0.028650           0.041158
# babies                            -0.020543  -0.003614          -0.023334
# is_repeated_guest                 -0.089643  -0.147003           0.024343
# previous_cancellations             0.051468   0.005375          -0.054212
# ...

# %%
num_df_final = ready_df[['lead_time','previous_cancellations','previous_bookings_not_canceled','booking_changes',
                         'days_in_waiting_list','adr','required_car_parking_spaces','total_of_special_requests','total_stay','total_people']].corr()

# %%
f, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(num_df_final, annot = True, fmt='.2f', annot_kws={'size': 10},  vmax=.8, square=True, cmap="cubehelix")
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To identify potential links between variables and evaluate the degree of these correlations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.  The total_stay and the lead_time have a slight correlation. This could imply that for longer hotel stays, people generally plan little ahead of time.
# 2.   Adr is slightly correlated with total_people, which makes sense because more people means more revenue, and thus more adr.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# The customer behavioural patterns shown in the above insights can be utilized by the hotel business to generate revenue.

# %%
# Let's analyse the impact of the length of stay on the adr.

plt.figure(figsize = (12,6),dpi=200)
sns.scatterplot(y = 'adr', x = 'total_stay', data = ready_df)
plt.show()

# %% [markdown]
# We notice an outlier in adr, so we will remove it for a better scatter plot.

# %%
ready_df.drop(ready_df[ready_df['adr'] > 1000].index, inplace = True)

# %%
plt.figure(figsize = (12,6),dpi=200)
sns.scatterplot(y = 'adr', x = 'total_stay', data = ready_df)
plt.show()

# %% [markdown]
# The scatter plot indicates that the adr decreases as overall stay increases. This suggests that a good deal for the client can be achieved for an extended stay.

# %% [markdown]
# # **Business Objective**

# %% [markdown]
# **What do you suggest the client to achieve Business Objective ?**

# %% [markdown]
#  **Business objective attained as follows:**
#
#  The business goal for hotel analytics might change depending on the unique requirements and ambitions of a hotel, however some typical goals include:
#
# * **Improving guest satisfaction:** Hotels can find areas for improvement and implement adjustments to improve the guest experience by examining customer feedback.
#
# * **Increasing revenue:** Analytics can help hotels improve pricing, identify potential sales opportunities, and increase occupancy rates.
#
# * **Improving operational efficiency:** Analytics can assist hotels in identifying operational inefficiencies and making changes to reduce costs and increase productivity.
#
# * **Enhancing decision making:** Hotel analytics provide useful information that can guide important company choices, including marketing tactics, employee sizing, and expenditures on new technologies.
#
# * **Personalizing the guest experience:** Hotels may provide more individualized and memorable experiences for their visitors by evaluating guest data to customize their services and products to specific visitors.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1.City Hotel seems to be more preferred among travellers and it also generates more revenue.
#
# 2.Most number of bookings are made in July and August.
#
#
# 3.Room Type A is the most preferred room type among travellers.
#
# 4.Most number of bookings are made from Portugal.
#
# 5.Most of the guest stays for 1-4 days in the hotels.
#
# 6.Resort Hotel retains more number of guests.
#
# 7.Around one-fourth of the total bookings gets cancelled. More cancellations are from City Hotel.
#
# 8.New guest tends to cancel bookings more than repeated customers.
#
# 9.Lead time, number of days in waiting list or assignation of reserved room to customer does not affect cancellation of bookings.
#
# 10.Corporate has the most percentage of repeated guests while TA/TO has the least whereas in the case of cancelled bookings TA/TO has the most percentage while Corporate has the least.
#
# 11.The length of the stay decreases as ADR increases probably to reduce the cost.
#
# 12.Visits planned with longer stays are booked earlier than those planned with shorter stay.
